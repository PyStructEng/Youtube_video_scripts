# %% [markdown]
# ## Concrete Flexural Reinforcement Calculator

# %% [markdown]
# **Disclaimer of Warranty and Liability**
#   By using this a/scripp, you acknowledge and agree that the results it provides are for informational purposes only. The engineer using this tool is solely responsible for verifying and validating the accuracy of the results obtained. This ap/scriptp is provided "as is," without any warranty or guarantee of any kind, express or implied. In no event shall the developers or contributors be liable for any damages or consequences arising from the use of this ap/scriptp. You are encouraged to exercise due diligence and professional judgment when relying on the output of this tol"

# %%
# Import all the necessary library

# %%
import forallpeople
forallpeople.environment('structural',top_level = True)
import handcalcs.render
import math
from math import sqrt,pi

# %%
sqrt = math.sqrt

# %% [markdown]
# ### Section Parameters

# %% [markdown]
# ![image.png](attachment:01e2e09a-42f2-4588-990f-2e29654acd28.png)

# %%
# Inputs
M_f = 50    # kN-m
h_c = 250   # mm
b = 1200    # mm
cover = 20  # mm
d_b = 20    # mm
Phi_c = 0.65
f_prime_c = 30   # MPa
f_y = 400        # MPa

# %%
# %%render params
# M_f = 52.3    # kN-m
# h_c = 250   # mm
# b = 1200    # mm
# cover = 20  # mm
# d_b = 20    # mm
# Phi_c = 0.65
# f_prime_c = 30   # MPa
# f_y = 400        # MPa
# Out:
# \[
# \begin{aligned}
# M_{f} &= 52.300 \; \;\textrm{(kN-m)}
#  &h_{c} &= 250 \; \;\textrm{(mm)}
#  &b &= 1200 \; \;\textrm{(mm)}
# \\[10pt]
#  \mathrm{cover} &= 20 \; \;\textrm{(mm)}
#  &d_{b} &= 20 \; \;\textrm{(mm)}
#  &\Phi_{c} &= 0.650 \;
# \\[10pt]
#  f'_{c} &= 30 \; \;\textrm{(MPa)}
#  &f_{y} &= 400 \; \;\textrm{(MPa)}
# \end{aligned}
# \]

# %%
# Factored moment , M_f (kN-m)

# %%
# %%render
# M_f = M_f*10**6  # N-mm
# Out:
# \[
# \begin{aligned}
# M_{f} &= M_{f} \cdot \left( 10 \right) ^{ 6 }  = 52300000.000 \cdot \left( 10 \right) ^{ 6 } &= 52300000.000 \; \;\textrm{(N-mm)}
# \end{aligned}
# \]

# %%
# %%render long
# d = min(0.9*h_c,h_c-cover-(d_b/2)) # mm
# Out:
# \[
# \begin{aligned}
# d &= \operatorname{min} { \left( 0.9 \cdot h_{c} ,\  h_{c} - \mathrm{cover} - \left( \frac{ d_{b} }{ 2 } \right) \right) } \\&= \operatorname{min} { \left( 0.9 \cdot 250 ,\  250 - 20 - \left( \frac{ 20 }{ 2 } \right) \right) } \\&= 220.000 \; \;\textrm{(mm)}\\[10pt]
# \end{aligned}
# \]

# %%
# We can use the following formula to estimate the required reinforcement area

# %% [markdown]
# ![image.png](attachment:8e8f3168-fbc0-4cd4-84e1-a0dcb25b9cc3.png)

# %%
# %%render long
# As_req = 0.0015*f_prime_c*b*(d-sqrt(d**2-(3.85*M_f)/(f_prime_c*b)))  # Required reinforcement area (mm$^2$/m)
# Out:
# \[
# \begin{aligned}
# \mathrm{As}_{req} &= 0.0015 \cdot f'_{c} \cdot b \cdot \left( d - \sqrt { \left( d \right) ^{ 2 } - \frac{ 3.85 \cdot M_{f} }{ f'_{c} \cdot b } } \right) \\&= 0.0015 \cdot 30 \cdot 1200 \cdot \left( 220.000 - \sqrt { \left( 220.000 \right) ^{ 2 } - \frac{ 3.85 \cdot 52300000.000 }{ 30 \cdot 1200 } } \right) \\&= 707.505 \; \;\textrm{(Required reinforcement area (mm$^2$/m))}\\[10pt]
# \end{aligned}
# \]
